# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd 
print(pd.__version__)
"C:/Users/Lenovo/Downloads/New folder/file_name.csv"
# Out:
# 2.1.4
# 'C:/Users/Lenovo/Downloads/New folder/file_name.csv'

# %%
df = pd.read_csv("C:/Users/Lenovo/Downloads/spotify_top_songs_audio_features (1).csv")

# %%
df.head() #  head() --> used to diplay the  only 1st 5 row from the data_frame(by default)
df.head(100)
# Out:
#                         id                artist_names  \
# 0   000xQL6tZNLJzIrtIgxqSl         ZAYN, PARTYNEXTDOOR
# 1   003eoIwxETJujVWmNFMoZy                Alessia Cara
# 2   003vvx7Niy0yvhvHt4a68B                 The Killers
# 3   00B7TZ0Xawar6NZ00JFomN  Cardi B, Chance the Rapper
# 4   00Blm7zeNqgYLPtW6zg8cj     Post Malone, The Weeknd
# ..                     ...                         ...
# 95  06Gyf2pFDVmN5K8XAawG96          Future, Young Thug
# 96  06JvOZ39sK8D8SqiqfaxDU    Kanye West, XXXTENTACION
# 97  06Qo2fYR2KS1F7bL338iVT      Jung Kook, Major Lazer
# 98  06qMRF18gwbOYYbnP2du6i                       Wham!
# 99  06s3QtMJVXw1AJX3UfvZG1         Anuel AA, Bad Bunny
#
#                               track_name  \
# 0   Still Got Time (feat. PARTYNEXTDOOR)
# 1                          Growing Pains
# 2                         Mr. Brightside
# 3    Best Life (feat. Chance The Rapper)
# 4        One Right Now (with The Weeknd)
# ..                                   ...
# ...

# %%
df.info # show information about the data set
# Out:
# <bound method DataFrame.info of                           id                         artist_names  \
# 0     000xQL6tZNLJzIrtIgxqSl                  ZAYN, PARTYNEXTDOOR
# 1     003eoIwxETJujVWmNFMoZy                         Alessia Cara
# 2     003vvx7Niy0yvhvHt4a68B                          The Killers
# 3     00B7TZ0Xawar6NZ00JFomN           Cardi B, Chance the Rapper
# 4     00Blm7zeNqgYLPtW6zg8cj              Post Malone, The Weeknd
# ...                      ...                                  ...
# 6508  7zgqtptZvhf8GEmdsM2vp2                         Taylor Swift
# 6509  7zjEyeBsaw9gV0jofJLfOM  Young Thug, A$AP Rocky, Post Malone
# 6510  7zl7kehxesNEo2pYkKXTSe          Eminem, Jack Harlow, Cordae
# 6511  7zvfDihYiJ8RQ1nRcpKBF5          Kendrick Lamar, Tanna Leone
# 6512  7zxRMhXxJMQCeDDg0rKAVo                      NAV, The Weeknd
#
#                                        track_name  \
# 0            Still Got Time (feat. PARTYNEXTDOOR)
# ...

# %%
df # it will show all the col and rows in df(data_frame)
# Out:
#                           id                         artist_names  \
# 0     000xQL6tZNLJzIrtIgxqSl                  ZAYN, PARTYNEXTDOOR
# 1     003eoIwxETJujVWmNFMoZy                         Alessia Cara
# 2     003vvx7Niy0yvhvHt4a68B                          The Killers
# 3     00B7TZ0Xawar6NZ00JFomN           Cardi B, Chance the Rapper
# 4     00Blm7zeNqgYLPtW6zg8cj              Post Malone, The Weeknd
# ...                      ...                                  ...
# 6508  7zgqtptZvhf8GEmdsM2vp2                         Taylor Swift
# 6509  7zjEyeBsaw9gV0jofJLfOM  Young Thug, A$AP Rocky, Post Malone
# 6510  7zl7kehxesNEo2pYkKXTSe          Eminem, Jack Harlow, Cordae
# 6511  7zvfDihYiJ8RQ1nRcpKBF5          Kendrick Lamar, Tanna Leone
# 6512  7zxRMhXxJMQCeDDg0rKAVo                      NAV, The Weeknd
#
#                                        track_name  \
# 0            Still Got Time (feat. PARTYNEXTDOOR)
# 1                                   Growing Pains
# ...

# %%
df.columns  # shows to  col  name from the dataset
# Out:
# Index(['id', 'artist_names', 'track_name', 'source', 'key', 'mode',
#        'time_signature', 'danceability', 'energy', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'loudness',
#        'tempo', 'duration_ms', 'weeks_on_chart', 'streams'],
#       dtype='object')

# %%
df.shape # shows to total number of row & col from the dataset
# Out:
# (6513, 19)

# %%
df.count()
# Out:
# id                  6513
# artist_names        6513
# track_name          6513
# source              6513
# key                 6513
# mode                6513
# time_signature      6513
# danceability        6513
# energy              6513
# speechiness         6513
# acousticness        6513
# instrumentalness    6513
# liveness            6513
# valence             6513
# loudness            6513
# tempo               6513
# duration_ms         6513
# weeks_on_chart      6513
# streams             6513
# dtype: int64

# %%
df.nunique()
# Out:
# id                  6513
# artist_names        3001
# track_name          5351
# source               967
# key                   12
# mode                   2
# time_signature         4
# danceability         686
# energy               805
# speechiness         1146
# acousticness        2020
# instrumentalness    1833
# liveness            1071
# valence             1013
# loudness            4255
# tempo               5353
# duration_ms         5460
# weeks_on_chart       159
# streams             6513
# dtype: int64

# %%
import plotly.express as px # for  data visualization i.e provides functions to visualize a variety of types of data
import matplotlib.pyplot as plt # to plot  diffrent charts

# %%
import matplotlib.pyplot as plt

# %%
df.tail()
# Out:
#                           id                         artist_names  \
# 6508  7zgqtptZvhf8GEmdsM2vp2                         Taylor Swift
# 6509  7zjEyeBsaw9gV0jofJLfOM  Young Thug, A$AP Rocky, Post Malone
# 6510  7zl7kehxesNEo2pYkKXTSe          Eminem, Jack Harlow, Cordae
# 6511  7zvfDihYiJ8RQ1nRcpKBF5          Kendrick Lamar, Tanna Leone
# 6512  7zxRMhXxJMQCeDDg0rKAVo                      NAV, The Weeknd
#
#                                        track_name  \
# 6508                             ...Ready For It?
# 6509  Livin It Up (with Post Malone & A$AP Rocky)
# 6510  Killer (feat. Jack Harlow & Cordae) - Remix
# 6511                                   Mr. Morale
# 6512                                     Some Way
#
#                                                  source key   mode  \
# 6508                           Big Machine Records, LLC   D  Major
# 6509                              300 Entertainment/Atl   G  Major
# ...

# %%
df.tail()
# Out:
#                           id                         artist_names  \
# 6508  7zgqtptZvhf8GEmdsM2vp2                         Taylor Swift
# 6509  7zjEyeBsaw9gV0jofJLfOM  Young Thug, A$AP Rocky, Post Malone
# 6510  7zl7kehxesNEo2pYkKXTSe          Eminem, Jack Harlow, Cordae
# 6511  7zvfDihYiJ8RQ1nRcpKBF5          Kendrick Lamar, Tanna Leone
# 6512  7zxRMhXxJMQCeDDg0rKAVo                      NAV, The Weeknd
#
#                                        track_name  \
# 6508                             ...Ready For It?
# 6509  Livin It Up (with Post Malone & A$AP Rocky)
# 6510  Killer (feat. Jack Harlow & Cordae) - Remix
# 6511                                   Mr. Morale
# 6512                                     Some Way
#
#                                                  source key   mode  \
# 6508                           Big Machine Records, LLC   D  Major
# 6509                              300 Entertainment/Atl   G  Major
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6513 entries, 0 to 6512
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                6513 non-null   object
#  1   artist_names      6513 non-null   object
#  2   track_name        6513 non-null   object
#  3   source            6513 non-null   object
#  4   key               6513 non-null   object
#  5   mode              6513 non-null   object
#  6   time_signature    6513 non-null   object
#  7   danceability      6513 non-null   float64
#  8   energy            6513 non-null   float64
#  9   speechiness       6513 non-null   float64
#  10  acousticness      6513 non-null   float64
#  11  instrumentalness  6513 non-null   float64
#  12  liveness          6513 non-null   float64
#  13  valence           6513 non-null   float64
#  14  loudness          6513 non-null   float64
#  15  tempo             6513 non-null   float64
# ...
